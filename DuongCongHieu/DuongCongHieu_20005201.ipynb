# %%
import firebase_admin
from firebase_admin import credentials, firestore
import pandas as pd

# %%
df=pd.read_csv("orginal_sales_data_edit.csv",encoding="utf-8",header=0,delimiter=',')

# %%
df.head(5)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 0   2/24/2003  Shipped       1         2     2003  ...          NaN
# 1    5/7/2003  Shipped       2         5     2003  ...          NaN
# 2    7/1/2003  Shipped       3         7     2003  ...          NaN
# 3   8/25/2003  Shipped       3         8     2003  ...          NaN
# 4  10/10/2003  Shipped       4        10     2003  ...          NaN
#
#             CITY STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME  \
# 0            NYC    NY      10022     USA       NaN              Yu
# ...

# %%
cred=credentials.Certificate("./iuh-20005201-c6660-firebase-adminsdk-e6q8v-d8f9173763.json")
app=firebase_admin.initialize_app(cred)

# %%
dbFireStore=firestore.client()
for item in df.to_dict(orient='records'):
    doc_ref = dbFireStore.collection("tbl-20005201").document()
    doc_ref.set(item)

# %%
queryResults = list(dbFireStore.collection(u'tbl-20005201').stream())
listQueryResult = list(map(lambda x : x.to_dict(), queryResults))
df = pd.DataFrame(listQueryResult)
df
# Out:
#      TERRITORY  ORDERLINENUMBER  SUBCATEGORY        CITY   STATUS  \
# 0         EMEA                3        Table        Koln  Shipped
# 1         EMEA                2         Lamp  Manchester  Shipped
# 2         EMEA                9        Table        Oulu  Shipped
# 3         EMEA               14       Eraser      Nantes  Shipped
# 4         EMEA                9    Bookshelf        Koln  Shipped
# ...        ...              ...          ...         ...      ...
# 2818      APAC                9  Smart watch   Chatswood  Shipped
# 2819       NaN                2         Desk         NYC  Shipped
# 2820      EMEA                2       Eraser        Koln  Shipped
# 2821       NaN                5          Pen         NYC  Shipped
# 2822       NaN                2    Bookshelf    Glendale  Shipped
#
#                                  ADDRESSLINE1 ADDRESSLINE2  YEAR_ID  \
# 0                          Mehrheimerstr. 369          NaN     2004
# ...

# %%
queryResults1 = list(dbFireStore.collection(u'tbl-20005201').where(u'COUNTRY', u'==', 'USA').stream())
listQueryResult1 = list(map(lambda x : x.to_dict(), queryResults1))
df1 = pd.DataFrame(listQueryResult1)
df1
# Out:
#       TERRITORY SUBCATEGORY  ORDERLINENUMBER           CITY    STATUS  \
# 0           NaN        Lamp                3   Philadelphia   Shipped
# 1           NaN        Lamp                7     Burlingame   Shipped
# 2           NaN     Cabinet                9  San Francisco   Shipped
# 3           NaN       Table                5       Pasadena  Resolved
# 4           NaN       Ruler               13     Brickhaven   Shipped
# ...         ...         ...              ...            ...       ...
# 999         NaN   Headphone                5         Boston   Shipped
# 1000        NaN       Table               11   Philadelphia   Shipped
# 1001        NaN        Desk                2            NYC   Shipped
# 1002        NaN         Pen                5            NYC   Shipped
# 1003        NaN   Bookshelf                2       Glendale   Shipped
#
#                    ADDRESSLINE1 ADDRESSLINE2  YEAR_ID CONTACTLASTNAME COUNTRY  \
# ...
